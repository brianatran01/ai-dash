# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (1.54.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (12.1.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (23.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (9.1.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-1.1.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12-py3-none-any.whl
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.19.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from yfinance) (6.33.5)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting cffi>=1.12.0 (from curl_cffi<0.14,>=0.7->yfinance)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Using cached yfinance-1.1.0-py2.py3-none-any.whl (129 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Using cached peewee-3.19.0-py3-none-any.whl (411 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Using cached websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: peewee, multitasking, websockets, soupsieve, pycparser, frozendict, cffi, beautifulsoup4, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [yfinance]/10 [cffi]
# Successfully installed beautifulsoup4-4.14.3 cffi-2.0.0 curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-3.19.0 pycparser-3.0 soupsieve-2.8.3 websockets-16.0 yfinance-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ta
# Out:
# Collecting ta
#   Using cached ta-0.11.0-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from ta) (2.4.2)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from ta) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from pandas->ta) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Installing collected packages: ta
# Successfully installed ta-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from matplotlib) (12.1.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/streamlitenv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 45.0 MB/s  0:00:00m0:00:01
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 48.4 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import yfinance as yf
import pandas as pd
import ta
import matplotlib.pyplot as plt

st.set_page_config(page_title="AI S&P 500 Market Dashboard", layout="wide")

# -----------------------------
# Sidebar
# -----------------------------
st.sidebar.title("AI Market Controls")

tickers = {
    "NVIDIA": "NVDA",
    "Microsoft": "MSFT",
    "Apple": "AAPL",
    "Google": "GOOGL",
    "Meta": "META",
    "Amazon": "AMZN"
}

selected_stock = st.sidebar.selectbox("Select AI Stock", list(tickers.keys()))
ticker = tickers[selected_stock]

start_date = st.sidebar.date_input("Start Date", pd.to_datetime("2023-01-01"))
end_date = st.sidebar.date_input("End Date", pd.to_datetime("today"))

# -----------------------------
# Data Download
# -----------------------------
data = yf.download(ticker, start=start_date, end=end_date)

st.title(f"{selected_stock} ({ticker}) — AI Market Signals")

if data.empty:
    st.warning("No data available.")
    st.stop()

# -----------------------------
# Technical Indicators
# -----------------------------
close = data["Close"].squeeze()

data["SMA_50"] = ta.trend.sma_indicator(close, window=50)
data["SMA_200"] = ta.trend.sma_indicator(close, window=200)
data["RSI"] = ta.momentum.rsi(close, window=14)

macd = ta.trend.MACD(close)
data["MACD"] = macd.macd()
data["MACD_Signal"] = macd.macd_signal()

# -----------------------------
# Price Chart
# -----------------------------
st.subheader("Price & Moving Averages")

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(data["Close"], label="Close Price")
ax.plot(data["SMA_50"], label="SMA 50")
ax.plot(data["SMA_200"], label="SMA 200")
ax.legend()
ax.grid()

st.pyplot(fig)

# -----------------------------
# RSI
# -----------------------------
st.subheader("Relative Strength Index (RSI)")

fig, ax = plt.subplots(figsize=(10, 2))
ax.plot(data["RSI"], color="purple")
ax.axhline(70, linestyle="--")
ax.axhline(30, linestyle="--")
ax.set_ylim(0, 100)
ax.grid()

st.pyplot(fig)

# -----------------------------
# MACD
# -----------------------------
st.subheader("MACD Indicator")

fig, ax = plt.subplots(figsize=(10, 3))
ax.plot(data["MACD"], label="MACD")
ax.plot(data["MACD_Signal"], label="Signal")
ax.legend()
ax.grid()

st.pyplot(fig)

# -----------------------------
# Signal Interpretation
# -----------------------------
latest_rsi = data["RSI"].iloc[-1]

st.subheader("AI Signal Summary")

if latest_rsi > 70:
    st.error("🔴 Overbought (Possible Pullback)")
elif latest_rsi < 30:
    st.success("🟢 Oversold (Potential Buy Zone)")
else:
    st.info("🟡 Neutral Momentum")
# Out:
# 2026-02-06 21:44:22.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# [*********************100%***********************]  1 of 1 completed
# 2026-02-06 21:44:22.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.444 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 21:44:22.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
streamlit run notebook.ipynb
# Out:
#   Cell In[14], line 1
#     streamlit run notebook.ipynb
#               ^
# SyntaxError: invalid syntax
